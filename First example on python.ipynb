# %%
x = 3

# %%
type(x)

# %%
y = 3.0

# %%
type(y)

# %%
z = int(3.1)

# %%
z

# %%
p = 4
q = 3.0
k = p/q
k

# %%
type(k)

# %%
b = True

# %%
type(b)

# %%
S = 'caaaaaaaaat'

# %%
type(S)

# %%
j = 3

# %%
j

# %%
print 'I do not like more than ' +str(j)  +' icecreams'

# %%
S = S.capitalize()

# %%
S

# %%
S[-1]

# %%
len(S)

# %%
S1 = 'cat 123 xyz'
S2 = ' dog'
S1.split()

# %%
S1

# %%
s = ('cat', 'dog','man')

# %%
s

# %%
len(s)

# %%
l = list(s)

# %%
l

# %%
l[1]

# %%
l.append('wood')

# %%
l

# %%
l.pop()

# %%
l

# %%
l.append('man')

# %%
l.remove('man')

# %%
l

# %%
l

# %%
l1 = l

# %%
l1

# %%
l.append('man')

# %%
l1 = l[1:3]

# %%
l1

# %%
l.pop()

# %%
l

# %%
l1

# %%
dict = {'ram': 57,'shyam': 73,'hari': 35}

# %%
dict

# %%
dict['ram']

# %%
dict['shyam']

# %%
pwd

# %%
cd 'F:\sigma analytics & computing\training PPT\example data set'
# Out:
# F:\sigma analytics & computing\training PPT\example data set

# %%
dir(str)

# %%
dir(list)

# %%
dir(int)

# %%
ls

# %%
import os

# %%
input_file = open('house price data set.csv', 'r')

# %%
input_file
# Out:
# <open file 'house price data set.csv', mode 'r' at 0x0000000004193DB0>

# %%
l1 = []
for line in input_file:
    l1.append(line)
l1
# Out:
# ['P1,P5p1,P6p2,P11p4,P14p9,P15p1,P16p2,P18p2,P27p4,H2p2,H8p2,H10p1,H13p1,H18PA,H40P4,price\n',
#  '0.460869,0.0492522,0.2264698,0.1498266,0.7528365,0.0100567,0.5797286,0.0032513,0.0759118,0.6253178,0.0366129,0.9913769,0.2601165,0.0522456,0.7740586,130600\n',
#  '0.4709677,0.0025806,0.1374194,0.0963415,0.8625806,0,0.6951424,0.0050251,0.0435511,0.0642633,0.0033501,0.9949749,0.2852665,0.0606061,0.1428571,40500\n',
#  '0.4853406,0.0002109,0.1894115,0.1356557,0.8569922,0,0.6835836,0.0041429,0.0279648,0.0657958,0,0.9974107,0.315433,0.0651163,0.6875,28700\n',
#  '0.4989293,0,0.1006424,0.0854701,0.9079229,0,0.7804878,0.0060976,0.0182927,0.0574713,0,1,0.1494253,0.1395349,1,28500\n',
#  '0.4741935,0.6806452,0.2258065,0.1288344,0.8967742,0,0.7563025,0.0084034,0.0168067,0.0775194,0.6722689,0.9915966,0.1472868,0,0,24100\n',
#  '0.4750542,0.0867679,0.1301518,0.0950413,0.9240781,0,0.7926829,0,0.0060976,0.0888889,0.054878,0.9939024,0.2722222,0.2941176,0.5,14999\n',
# ...

# %%
l2 = []
for items in l1:
    string = str(items).strip().split()
    l2.append(string)

# %%
print ' hello %d %s' % (3, 'icecreams')
# Out:
#  hello 3 icecreams
